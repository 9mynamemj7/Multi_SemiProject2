# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
from glob import glob
import os, cv2
from tqdm import tqdm
import tensorflow as tf
seed = 2022
tf.random.set_seed(seed)
np.random.seed(seed)

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 1451086901153087834,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 6269894656
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 17339215096146492327
#  physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 2070 SUPER, pci bus id: 0000:07:00.0, compute capability: 7.5"]

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Embedding, Dropout, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# 이미지 확인

# %%
img_path = "C:/workspace/04.SecondProject/images"
img_cha = "pie"
img_src = cv2.imread(f"{img_path}/{img_cha}/{img_cha} (1).jpg", cv2.IMREAD_COLOR)
orig_img = cv2.cvtColor(img_src, cv2.COLOR_BGR2RGB)
gray_img = cv2.cvtColor(img_src, cv2.COLOR_BGR2GRAY)

plt.figure(figsize=(12,8))
plt.subplot(1,3,3)
plt.title("gray_img")
plt.imshow(gray_img, cmap='gray')
plt.subplot(1,3,2)
plt.title("orig_img")
plt.imshow(orig_img)
plt.subplot(1,3,1)
plt.title("img_src")
plt.imshow(img_src)

plt.figure(figsize=(4,8))
plt.title("GRAYSCALE")
img = cv2.imread(f"{img_path}/{img_cha}/{img_cha} (1).jpg", cv2.IMREAD_GRAYSCALE)
plt.imshow(img, cmap='gray')

# %%
cha_list = ['isang', 'jammanbo', 'evee', 'pie', 'squirtle', 'pikachu', 'jiwoo', 'leeseul']
X = []
y = []
err = []

for idx, img_cha in enumerate(tqdm(cha_list)):
    filepath = f"{img_path}/{img_cha}"
    for fname in os.listdir(filepath):
        img = cv2.imread(f'{filepath}/{fname}', cv2.IMREAD_COLOR)
        try:
            gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            resize_img = cv2.resize(gray_img, dsize=(128, 128), interpolation= cv2.INTER_LINEAR)
            
            blur = cv2.GaussianBlur(resize_img, ksize = (5, 5), sigmaX = 0)
            
            X.append(blur / 256)
            y.append(idx)

        except:
            err.append(fname)
            continue
        
X = np.array(X)
y = np.array(y)

print('\n에러:','None' if len(err) == 0 else err)
# Out:
# 100%|██████████| 8/8 [00:07<00:00,  1.01it/s]
# 에러: None

# %%
X.shape, y.shape
# Out:
# ((4000, 128, 128), (4000,))

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size = 0.2, stratify = y, random_state = seed
)

# X_train, X_valid, Y_train, Y_valid = train_test_split(
#     X_train, y_train, stratify = y_train, test_size = 0.2, random_state = seed
# )
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((3200, 128, 128), (800, 128, 128), (3200,), (800,))

# %%
# X_train, X_test 정규화 (0 ~ 1), 이미지 차원 변경: 2차원 --> 3차원
X_train = X_train.reshape(-1, 128, 128, 1) / 255.
X_test = X_test.reshape(-1, 128, 128, 1) / 255.
X_train.shape, X_test.shape
# Out:
# ((3200, 128, 128, 1), (800, 128, 128, 1))

# %%
# y_data: one-hot encoding
Y_train = to_categorical(y_train)
Y_test = to_categorical(y_test)
Y_train.shape, Y_test.shape
# Out:
# ((3200, 8), (800, 8))

# %%
with tf.device("/device:CPU:0"):
    model = Sequential([
    Conv2D(32, (3, 3), input_shape = (128,128,1), padding = 'same', activation = 'relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    Conv2D(64, (3, 3), padding = 'same', activation = 'relu'),
    Conv2D(64, (3, 3), activation = 'relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(8, activation = 'softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 128, 128, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 64)        18496
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 62, 62, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 31, 31, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 31, 31, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 61504)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               15745280
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 2056
# =================================================================
# Total params: 15,803,080
# Trainable params: 15,803,080
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile('adam', 'categorical_crossentropy', ['accuracy'])

model_path = './gray_delNois_adam.h5'
mc = ModelCheckpoint(model_path, moniter = 'val_loss', verbose = 0, save_best_only = True)
es = EarlyStopping(patience = 15)

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, Y_train, Y_valid = train_test_split(
    X_train, Y_train, stratify=Y_train, test_size=0.2, random_state=seed
)

# %% [markdown]
# ### 부풀리기 적용 O

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rotation_range=10,          # randomly rotate images in the range 15 degree
    width_shift_range=0.1,      # randomly shift images horizontally 
    height_shift_range=0.1,     # randomly shift images vertically
    shear_range=0.1,            # 도형의 기울기
    zoom_range=[0.8,1.2],       # 0.8~1.2 배 크기로 임의로 확대/축소
    horizontal_flip=True,       # randomly flip images
    vertical_flip=False,        # randomly flip images
    fill_mode='nearest'         # set mode for filling points outside the input boundaries
)

# %%
datagen.fit(X_train)

# %%
with tf.device("/device:GPU:0"):
    hist1 = model.fit(
    datagen.flow(X_train, Y_train, batch_size=32),
    validation_data=(X_valid, Y_valid), epochs = 100, callbacks=[mc, es]
    )
# Out:
# Epoch 1/100
# 80/80 [==============================] - 8s 57ms/step - loss: 2.0812 - accuracy: 0.1180 - val_loss: 2.0795 - val_accuracy: 0.1250
#
# Epoch 00001: val_loss improved from inf to 2.07947, saving model to .\gray_delNois_adam.h5
# Epoch 2/100
# 80/80 [==============================] - 5s 56ms/step - loss: 2.0799 - accuracy: 0.1219 - val_loss: 2.0795 - val_accuracy: 0.1250
#
# Epoch 00002: val_loss improved from 2.07947 to 2.07946, saving model to .\gray_delNois_adam.h5
# Epoch 3/100
# 80/80 [==============================] - 5s 56ms/step - loss: 2.0799 - accuracy: 0.1148 - val_loss: 2.0795 - val_accuracy: 0.1250
#
# Epoch 00003: val_loss did not improve from 2.07946
# Epoch 4/100
# 80/80 [==============================] - 4s 56ms/step - loss: 2.0796 - accuracy: 0.1238 - val_loss: 2.0795 - val_accuracy: 0.1250
#
# Epoch 00004: val_loss improved from 2.07946 to 2.07945, saving model to .\gray_delNois_adam.h5
# Epoch 5/100
# 80/80 [==============================] - 4s 55ms/step - loss: 2.0796 - accuracy: 0.1156 - val_loss: 2.0795 - val_accuracy: 0.1250
#
# Epoch 00005: val_loss did not improve from 2.07945
# Epoch 6/100
# 80/80 [==============================] - 4s 56ms/step - loss: 2.0799 - accuracy: 0.1160 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00006: val_loss improved from 2.07945 to 2.07945, saving model to .\gray_delNois_adam.h5
# Epoch 7/100
# 80/80 [==============================] - 4s 55ms/step - loss: 2.0799 - accuracy: 0.1195 - val_loss: 2.0795 - val_accuracy: 0.1250
#
# Epoch 00007: val_loss did not improve from 2.07945
# Epoch 8/100
# 80/80 [==============================] - 4s 55ms/step - loss: 2.0796 - accuracy: 0.1242 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00008: val_loss did not improve from 2.07945
# Epoch 9/100
# 80/80 [==============================] - 4s 54ms/step - loss: 2.0798 - accuracy: 0.1105 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00009: val_loss did not improve from 2.07945
# Epoch 10/100
# 80/80 [==============================] - 4s 54ms/step - loss: 2.0797 - accuracy: 0.1125 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00010: val_loss improved from 2.07945 to 2.07944, saving model to .\gray_delNois_adam.h5
# Epoch 11/100
# 80/80 [==============================] - 4s 54ms/step - loss: 2.0798 - accuracy: 0.1191 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00011: val_loss improved from 2.07944 to 2.07944, saving model to .\gray_delNois_adam.h5
# Epoch 12/100
# 80/80 [==============================] - 4s 54ms/step - loss: 2.0797 - accuracy: 0.1191 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00012: val_loss did not improve from 2.07944
# Epoch 13/100
# 80/80 [==============================] - 4s 54ms/step - loss: 2.0797 - accuracy: 0.1137 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00013: val_loss did not improve from 2.07944
# Epoch 14/100
# 80/80 [==============================] - 4s 54ms/step - loss: 2.0796 - accuracy: 0.1113 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00014: val_loss did not improve from 2.07944
# Epoch 15/100
# 80/80 [==============================] - 4s 54ms/step - loss: 2.0797 - accuracy: 0.1184 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00015: val_loss did not improve from 2.07944
# Epoch 16/100
# 80/80 [==============================] - 4s 54ms/step - loss: 2.0797 - accuracy: 0.1121 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00016: val_loss improved from 2.07944 to 2.07944, saving model to .\gray_delNois_adam.h5
# Epoch 17/100
# 80/80 [==============================] - 4s 55ms/step - loss: 2.0796 - accuracy: 0.1129 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00017: val_loss improved from 2.07944 to 2.07944, saving model to .\gray_delNois_adam.h5
# Epoch 18/100
# 80/80 [==============================] - 5s 57ms/step - loss: 2.0797 - accuracy: 0.1031 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00018: val_loss did not improve from 2.07944
# Epoch 19/100
# 80/80 [==============================] - 4s 56ms/step - loss: 2.0796 - accuracy: 0.1180 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00019: val_loss did not improve from 2.07944
# Epoch 20/100
# 80/80 [==============================] - 4s 54ms/step - loss: 2.0797 - accuracy: 0.1176 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00020: val_loss did not improve from 2.07944
# Epoch 21/100
# 80/80 [==============================] - 4s 55ms/step - loss: 2.0797 - accuracy: 0.1055 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00021: val_loss did not improve from 2.07944
# Epoch 22/100
# 80/80 [==============================] - 4s 54ms/step - loss: 2.0797 - accuracy: 0.1117 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00022: val_loss did not improve from 2.07944
# Epoch 23/100
# 80/80 [==============================] - 4s 54ms/step - loss: 2.0797 - accuracy: 0.1129 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00023: val_loss did not improve from 2.07944
# Epoch 24/100
# 80/80 [==============================] - 4s 55ms/step - loss: 2.0797 - accuracy: 0.1191 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00024: val_loss did not improve from 2.07944
# Epoch 25/100
# 80/80 [==============================] - 4s 54ms/step - loss: 2.0796 - accuracy: 0.1105 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00025: val_loss did not improve from 2.07944
# Epoch 26/100
# 80/80 [==============================] - 4s 55ms/step - loss: 2.0796 - accuracy: 0.1195 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00026: val_loss did not improve from 2.07944
# Epoch 27/100
# 80/80 [==============================] - 4s 54ms/step - loss: 2.0796 - accuracy: 0.1086 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00027: val_loss did not improve from 2.07944
# Epoch 28/100
# 80/80 [==============================] - 4s 54ms/step - loss: 2.0796 - accuracy: 0.1152 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00028: val_loss did not improve from 2.07944
# Epoch 29/100
# 80/80 [==============================] - 4s 54ms/step - loss: 2.0796 - accuracy: 0.1145 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00029: val_loss did not improve from 2.07944
# Epoch 30/100
# 80/80 [==============================] - 4s 54ms/step - loss: 2.0797 - accuracy: 0.1117 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00030: val_loss did not improve from 2.07944
# Epoch 31/100
# 80/80 [==============================] - 4s 54ms/step - loss: 2.0796 - accuracy: 0.1148 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00031: val_loss did not improve from 2.07944
# Epoch 32/100
# 80/80 [==============================] - 4s 54ms/step - loss: 2.0796 - accuracy: 0.1148 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00032: val_loss did not improve from 2.07944

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test, Y_test)
# Out:
# 25/25 [==============================] - 0s 6ms/step - loss: 2.0794 - accuracy: 0.1250
# [2.0794427394866943, 0.125]

# %%
y_acc = hist1.history['accuracy']
y_vloss = hist1.history['val_loss']
xs = np.arange(1, len(y_acc) + 1)

plt.figure(figsize = (12, 6))
plt.plot(xs, y_acc, label = 'accuracy')
plt.plot(xs, y_vloss, label = 'validation_loss')
plt.xlabel('Epoch')
plt.title('GRAY')
plt.legend(), plt.grid()
plt.show()

# %% [markdown]
# ### 부풀리기 적용 X

# %%
model_path2 = './gray_delNois_NoGen_adam.h5'
mc2 = ModelCheckpoint(model_path2, moniter = 'val_loss', verbose = 1, save_best_only = True)
es2 = EarlyStopping(patience = 10)

# %%
with tf.device("/device:GPU:0"):
    hist2 = model.fit(
    X_train, Y_train, validation_split=0.2, epochs=100, batch_size=200,
    callbacks=[mc2,es2])
# Out:
# Epoch 1/100
# 11/11 [==============================] - 5s 212ms/step - loss: 2.0794 - accuracy: 0.1240 - val_loss: 2.0795 - val_accuracy: 0.1289
#
# Epoch 00001: val_loss improved from inf to 2.07947, saving model to .\gray_delNois_NoGen_adam.h5
# Epoch 2/100
# 11/11 [==============================] - 1s 123ms/step - loss: 2.0794 - accuracy: 0.1240 - val_loss: 2.0795 - val_accuracy: 0.1230
#
# Epoch 00002: val_loss did not improve from 2.07947
# Epoch 3/100
# 11/11 [==============================] - 1s 123ms/step - loss: 2.0794 - accuracy: 0.1255 - val_loss: 2.0796 - val_accuracy: 0.1230
#
# Epoch 00003: val_loss did not improve from 2.07947
# Epoch 4/100
# 11/11 [==============================] - 1s 123ms/step - loss: 2.0794 - accuracy: 0.1260 - val_loss: 2.0796 - val_accuracy: 0.1113
#
# Epoch 00004: val_loss did not improve from 2.07947
# Epoch 5/100
# 11/11 [==============================] - 1s 122ms/step - loss: 2.0794 - accuracy: 0.1284 - val_loss: 2.0797 - val_accuracy: 0.1113
#
# Epoch 00005: val_loss did not improve from 2.07947
# Epoch 6/100
# 11/11 [==============================] - 1s 122ms/step - loss: 2.0794 - accuracy: 0.1284 - val_loss: 2.0797 - val_accuracy: 0.1113
#
# Epoch 00006: val_loss did not improve from 2.07947
# Epoch 7/100
# 11/11 [==============================] - 1s 122ms/step - loss: 2.0794 - accuracy: 0.1284 - val_loss: 2.0797 - val_accuracy: 0.1113
#
# Epoch 00007: val_loss did not improve from 2.07947
# Epoch 8/100
# 11/11 [==============================] - 1s 123ms/step - loss: 2.0794 - accuracy: 0.1284 - val_loss: 2.0798 - val_accuracy: 0.1113
#
# Epoch 00008: val_loss did not improve from 2.07947
# Epoch 9/100
# 11/11 [==============================] - 1s 122ms/step - loss: 2.0794 - accuracy: 0.1284 - val_loss: 2.0798 - val_accuracy: 0.1113
#
# Epoch 00009: val_loss did not improve from 2.07947
# Epoch 10/100
# 11/11 [==============================] - 1s 123ms/step - loss: 2.0794 - accuracy: 0.1284 - val_loss: 2.0798 - val_accuracy: 0.1113
#
# Epoch 00010: val_loss did not improve from 2.07947
# Epoch 11/100
# 11/11 [==============================] - 1s 123ms/step - loss: 2.0794 - accuracy: 0.1284 - val_loss: 2.0798 - val_accuracy: 0.1113
#
# Epoch 00011: val_loss did not improve from 2.07947

# %%
best_model2 = load_model(model_path2)
best_model2.evaluate(X_test, Y_test)
# Out:
# 25/25 [==============================] - 1s 8ms/step - loss: 2.0794 - accuracy: 0.1250
# [2.079442024230957, 0.125]

# %%
y_acc = hist1.history['accuracy']
y_vloss = hist1.history['val_loss']
xs = np.arange(1, len(y_acc) + 1)

plt.figure(figsize = (12, 6))
plt.plot(xs, y_acc, label = 'accuracy')
plt.plot(xs, y_vloss, label = 'validation_loss')
plt.xlabel('Epoch')
plt.title('gray_delNois_NoGen_adam')
plt.legend(), plt.grid()
plt.show()

# %% [markdown]
# ### 다른 모델링

# %% [markdown]
# - 부풀리기랑 컴파일 바꿈

# %%
datagen2 = ImageDataGenerator(
    rescale=1/255.,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.5,
    zoom_range=[0.8,1.5],
    horizontal_flip=True,
    vertical_flip=False,
    fill_mode='nearest'
)

# %%
datagen2.fit(X_train)

# %%
with tf.device("/device:CPU:0"):
    model = Sequential([
    Conv2D(32, (3, 3), input_shape = (128,128,1), padding = 'same', activation = 'relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    Conv2D(64, (3, 3), padding = 'same', activation = 'relu'),
    Conv2D(64, (3, 3), activation = 'relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(8, activation = 'softmax')
])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 128, 128, 32)      320
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 64, 64, 32)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 64, 64, 64)        18496
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 62, 62, 64)        36928
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 31, 31, 64)        0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 31, 31, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 61504)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               15745280
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 8)                 2056
# =================================================================
# Total params: 15,803,080
# Trainable params: 15,803,080
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer=RMSprop(learning_rate=0.0001, decay=1e-6),
    loss='categorical_crossentropy', metrics=['accuracy']
)
model_path3 = './gray_delNois_rms.h5'
mc3 = ModelCheckpoint(model_path3, moniter = 'val_loss', verbose = 0, save_best_only = True)
es3 = EarlyStopping(patience = 15)

# %%
with tf.device("/device:GPU:0"):
    hist3 = model.fit(
    datagen2.flow(X_train, Y_train, batch_size=32),
    validation_data=(X_valid, Y_valid), epochs = 100, callbacks=[mc3, es3]
    )
# Out:
# Epoch 1/100
# 80/80 [==============================] - 11s 122ms/step - loss: 2.0796 - accuracy: 0.1199 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00001: val_loss improved from inf to 2.07944, saving model to .\gray_delNois_rms.h5
# Epoch 2/100
# 80/80 [==============================] - 10s 121ms/step - loss: 2.0795 - accuracy: 0.1160 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00002: val_loss improved from 2.07944 to 2.07944, saving model to .\gray_delNois_rms.h5
# Epoch 3/100
# 80/80 [==============================] - 10s 120ms/step - loss: 2.0795 - accuracy: 0.1211 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00003: val_loss did not improve from 2.07944
# Epoch 4/100
# 80/80 [==============================] - 10s 121ms/step - loss: 2.0795 - accuracy: 0.1180 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00004: val_loss did not improve from 2.07944
# Epoch 5/100
# 80/80 [==============================] - 10s 121ms/step - loss: 2.0795 - accuracy: 0.1191 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00005: val_loss did not improve from 2.07944
# Epoch 6/100
# 80/80 [==============================] - 10s 120ms/step - loss: 2.0795 - accuracy: 0.1195 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00006: val_loss did not improve from 2.07944
# Epoch 7/100
# 80/80 [==============================] - 10s 120ms/step - loss: 2.0795 - accuracy: 0.1172 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00007: val_loss did not improve from 2.07944
# Epoch 8/100
# 80/80 [==============================] - 10s 120ms/step - loss: 2.0795 - accuracy: 0.1195 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00008: val_loss improved from 2.07944 to 2.07944, saving model to .\gray_delNois_rms.h5
# Epoch 9/100
# 80/80 [==============================] - 10s 120ms/step - loss: 2.0795 - accuracy: 0.1223 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00009: val_loss did not improve from 2.07944
# Epoch 10/100
# 80/80 [==============================] - 10s 121ms/step - loss: 2.0795 - accuracy: 0.1137 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00010: val_loss did not improve from 2.07944
# Epoch 11/100
# 80/80 [==============================] - 10s 122ms/step - loss: 2.0795 - accuracy: 0.1227 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00011: val_loss did not improve from 2.07944
# Epoch 12/100
# 80/80 [==============================] - 10s 120ms/step - loss: 2.0795 - accuracy: 0.1156 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00012: val_loss did not improve from 2.07944
# Epoch 13/100
# 80/80 [==============================] - 10s 120ms/step - loss: 2.0795 - accuracy: 0.1270 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00013: val_loss did not improve from 2.07944
# Epoch 14/100
# 80/80 [==============================] - 10s 121ms/step - loss: 2.0794 - accuracy: 0.1223 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00014: val_loss did not improve from 2.07944
# Epoch 15/100
# 80/80 [==============================] - 10s 122ms/step - loss: 2.0794 - accuracy: 0.1121 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00015: val_loss did not improve from 2.07944
# Epoch 16/100
# 80/80 [==============================] - 10s 119ms/step - loss: 2.0795 - accuracy: 0.1199 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00016: val_loss did not improve from 2.07944
# Epoch 17/100
# 80/80 [==============================] - 10s 119ms/step - loss: 2.0795 - accuracy: 0.1117 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00017: val_loss did not improve from 2.07944
# Epoch 18/100
# 80/80 [==============================] - 10s 122ms/step - loss: 2.0795 - accuracy: 0.1234 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00018: val_loss did not improve from 2.07944
# Epoch 19/100
# 80/80 [==============================] - 10s 121ms/step - loss: 2.0794 - accuracy: 0.1250 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00019: val_loss did not improve from 2.07944
# Epoch 20/100
# 80/80 [==============================] - 10s 121ms/step - loss: 2.0795 - accuracy: 0.1211 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00020: val_loss did not improve from 2.07944
# Epoch 21/100
# 80/80 [==============================] - 10s 119ms/step - loss: 2.0795 - accuracy: 0.1285 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00021: val_loss improved from 2.07944 to 2.07944, saving model to .\gray_delNois_rms.h5
# Epoch 22/100
# 80/80 [==============================] - 10s 121ms/step - loss: 2.0795 - accuracy: 0.1098 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00022: val_loss did not improve from 2.07944
# Epoch 23/100
# 80/80 [==============================] - 9s 118ms/step - loss: 2.0795 - accuracy: 0.1172 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00023: val_loss did not improve from 2.07944
# Epoch 24/100
# 80/80 [==============================] - 10s 119ms/step - loss: 2.0794 - accuracy: 0.1227 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00024: val_loss did not improve from 2.07944
# Epoch 25/100
# 80/80 [==============================] - 9s 118ms/step - loss: 2.0795 - accuracy: 0.1187 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00025: val_loss did not improve from 2.07944
# Epoch 26/100
# 80/80 [==============================] - 9s 118ms/step - loss: 2.0795 - accuracy: 0.1164 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00026: val_loss did not improve from 2.07944
# Epoch 27/100
# 80/80 [==============================] - 10s 119ms/step - loss: 2.0795 - accuracy: 0.1223 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00027: val_loss did not improve from 2.07944
# Epoch 28/100
# 80/80 [==============================] - 10s 119ms/step - loss: 2.0795 - accuracy: 0.1246 - val_loss: 2.0794 - val_accuracy: 0.0984
#
# Epoch 00028: val_loss did not improve from 2.07944
# Epoch 29/100
# 80/80 [==============================] - 10s 119ms/step - loss: 2.0795 - accuracy: 0.1160 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00029: val_loss did not improve from 2.07944
# Epoch 30/100
# 80/80 [==============================] - 9s 118ms/step - loss: 2.0795 - accuracy: 0.1129 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00030: val_loss did not improve from 2.07944
# Epoch 31/100
# 80/80 [==============================] - 9s 118ms/step - loss: 2.0795 - accuracy: 0.1227 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00031: val_loss did not improve from 2.07944
# Epoch 32/100
# 80/80 [==============================] - 9s 118ms/step - loss: 2.0795 - accuracy: 0.1102 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00032: val_loss did not improve from 2.07944
# Epoch 33/100
# 80/80 [==============================] - 9s 118ms/step - loss: 2.0795 - accuracy: 0.1070 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00033: val_loss did not improve from 2.07944
# Epoch 34/100
# 80/80 [==============================] - 9s 118ms/step - loss: 2.0795 - accuracy: 0.1258 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00034: val_loss did not improve from 2.07944
# Epoch 35/100
# 80/80 [==============================] - 9s 118ms/step - loss: 2.0795 - accuracy: 0.1035 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00035: val_loss did not improve from 2.07944
# Epoch 36/100
# 80/80 [==============================] - 9s 118ms/step - loss: 2.0795 - accuracy: 0.1234 - val_loss: 2.0794 - val_accuracy: 0.1250
#
# Epoch 00036: val_loss did not improve from 2.07944

# %%
best_model = load_model(model_path3)
best_model.evaluate(X_test, Y_test)
# Out:
# 25/25 [==============================] - 1s 13ms/step - loss: 2.0794 - accuracy: 0.1250
# [2.079442024230957, 0.125]

# %%
y_acc = hist3.history['accuracy']
y_vloss = hist3.history['val_loss']
xs = np.arange(1, len(y_acc) + 1)

plt.figure(figsize = (12, 6))
plt.plot(xs, y_acc, label = 'accuracy')
plt.plot(xs, y_vloss, label = 'validation_loss')
plt.xlabel('Epoch')
plt.title('gray_delNois_rms')
plt.legend(), plt.grid()
plt.show()

# %% [markdown]
# #### 부풀리기만 더 바꿈

# %%
datagen4 = ImageDataGenerator(
    featurewise_center=False,   # set input mean to 0 over the dataset
    samplewise_center=False,    # set each sample mean to 0
    featurewise_std_normalization=False,    # divide inputs by std of dataset
    samplewise_std_normalization=False,     # divide each input by its std
    zca_whitening=False,    # apply ZCA whitening
    zca_epsilon=1e-06,      # epsilon for ZCA whitening
    rotation_range=0,       # randomly rotate images in the range (deg 0 to 180)
    width_shift_range=0.1,  # randomly shift images horizontally
    height_shift_range=0.1, # randomly shift images vertically
    shear_range=0.,         # set range for random shear
    zoom_range=0.1,         # set range for random zoom
    channel_shift_range=0., # set range for random channel shifts
    fill_mode='nearest',    # set mode for filling points outside the input boundaries
    cval=0.,                # value used for fill_mode = "constant"
    horizontal_flip=True,   # randomly flip images
    vertical_flip=False,    # randomly flip images
    rescale=None,           # set rescaling factor (applied before any other transformation)
    preprocessing_function=None,    # set function that will be applied on each input
    data_format=None,       # image data format, either "channels_first" or "channels_last"
    validation_split=0.0    # fraction of images reserved for validation
)

# %%
model_path4 = './gray_NewdelNois_rms.h5'
mc4 = ModelCheckpoint(model_path4, moniter = 'val_loss', verbose = 0, save_best_only = True)
es4 = EarlyStopping(patience = 10)

# %%
with tf.device("/device:GPU:0"):
    hist4 = model.fit(
    datagen4.flow(X_train, Y_train, batch_size=32), verbose=0,
    validation_data=(X_valid, Y_valid), epochs = 100, callbacks=[mc4, es4]
    )
# Out:
# Epoch 1/100
# 80/80 [==============================] - 11s 120ms/step - loss: 2.0798 - accuracy: 0.1242 - val_loss: 2.0791 - val_accuracy: 0.1281
# Epoch 2/100
# 80/80 [==============================] - 9s 118ms/step - loss: 2.0787 - accuracy: 0.1512 - val_loss: 2.0759 - val_accuracy: 0.1578
# Epoch 3/100
# 80/80 [==============================] - 10s 121ms/step - loss: 2.0729 - accuracy: 0.1543 - val_loss: 2.0651 - val_accuracy: 0.1422
# Epoch 4/100
# 80/80 [==============================] - 10s 120ms/step - loss: 2.0556 - accuracy: 0.1766 - val_loss: 2.0338 - val_accuracy: 0.2516
# Epoch 5/100
# 80/80 [==============================] - 10s 119ms/step - loss: 2.0284 - accuracy: 0.2039 - val_loss: 2.0030 - val_accuracy: 0.2609
# Epoch 6/100
# 80/80 [==============================] - 9s 118ms/step - loss: 2.0089 - accuracy: 0.2141 - val_loss: 1.9490 - val_accuracy: 0.2953
# Epoch 7/100
# 80/80 [==============================] - 9s 118ms/step - loss: 1.9683 - accuracy: 0.2363 - val_loss: 1.9048 - val_accuracy: 0.3141
# Epoch 8/100
# 80/80 [==============================] - 10s 120ms/step - loss: 1.9482 - accuracy: 0.2590 - val_loss: 1.8632 - val_accuracy: 0.3187
# Epoch 9/100
# 80/80 [==============================] - 10s 125ms/step - loss: 1.9137 - accuracy: 0.2852 - val_loss: 1.8246 - val_accuracy: 0.3141
# Epoch 10/100
# 80/80 [==============================] - 10s 123ms/step - loss: 1.8867 - accuracy: 0.2875 - val_loss: 1.7933 - val_accuracy: 0.3578
# Epoch 11/100
# 80/80 [==============================] - 10s 125ms/step - loss: 1.8571 - accuracy: 0.3000 - val_loss: 1.7430 - val_accuracy: 0.3562
# Epoch 12/100
# 80/80 [==============================] - 10s 120ms/step - loss: 1.8556 - accuracy: 0.3148 - val_loss: 1.7157 - val_accuracy: 0.3906
# Epoch 13/100
# 80/80 [==============================] - 10s 120ms/step - loss: 1.8185 - accuracy: 0.3187 - val_loss: 1.7067 - val_accuracy: 0.3812
# Epoch 14/100
# 80/80 [==============================] - 10s 119ms/step - loss: 1.8012 - accuracy: 0.3328 - val_loss: 1.6685 - val_accuracy: 0.3812
# Epoch 15/100
# 80/80 [==============================] - 9s 118ms/step - loss: 1.7862 - accuracy: 0.3402 - val_loss: 1.6503 - val_accuracy: 0.3984
# Epoch 16/100
# 80/80 [==============================] - 9s 118ms/step - loss: 1.7576 - accuracy: 0.3508 - val_loss: 1.6390 - val_accuracy: 0.4141
# Epoch 17/100
# 80/80 [==============================] - 10s 120ms/step - loss: 1.7590 - accuracy: 0.3605 - val_loss: 1.6254 - val_accuracy: 0.4266
# Epoch 18/100
# 80/80 [==============================] - 10s 120ms/step - loss: 1.7530 - accuracy: 0.3699 - val_loss: 1.5931 - val_accuracy: 0.4516
# Epoch 19/100
# 80/80 [==============================] - 10s 120ms/step - loss: 1.7531 - accuracy: 0.3594 - val_loss: 1.5920 - val_accuracy: 0.4547
# Epoch 20/100
# 80/80 [==============================] - 10s 122ms/step - loss: 1.7251 - accuracy: 0.3754 - val_loss: 1.5782 - val_accuracy: 0.4484
# Epoch 21/100
# 80/80 [==============================] - 10s 120ms/step - loss: 1.7212 - accuracy: 0.3805 - val_loss: 1.5490 - val_accuracy: 0.4688
# Epoch 22/100
# 80/80 [==============================] - 10s 120ms/step - loss: 1.7090 - accuracy: 0.3797 - val_loss: 1.5583 - val_accuracy: 0.4500
# Epoch 23/100
# 80/80 [==============================] - 10s 120ms/step - loss: 1.7010 - accuracy: 0.3895 - val_loss: 1.5567 - val_accuracy: 0.4641
# Epoch 24/100
# 80/80 [==============================] - 10s 119ms/step - loss: 1.6824 - accuracy: 0.4113 - val_loss: 1.5377 - val_accuracy: 0.4594
# Epoch 25/100
# 80/80 [==============================] - 10s 119ms/step - loss: 1.6728 - accuracy: 0.3984 - val_loss: 1.5090 - val_accuracy: 0.4828
# Epoch 26/100
# 80/80 [==============================] - 10s 120ms/step - loss: 1.6670 - accuracy: 0.4070 - val_loss: 1.4771 - val_accuracy: 0.5016
# Epoch 27/100
# 80/80 [==============================] - 10s 119ms/step - loss: 1.6642 - accuracy: 0.3977 - val_loss: 1.4696 - val_accuracy: 0.5141
# Epoch 28/100
# 80/80 [==============================] - 10s 120ms/step - loss: 1.6466 - accuracy: 0.4121 - val_loss: 1.4618 - val_accuracy: 0.5203
# Epoch 29/100
# 80/80 [==============================] - 10s 119ms/step - loss: 1.6415 - accuracy: 0.4301 - val_loss: 1.4623 - val_accuracy: 0.4891
# Epoch 30/100
# 80/80 [==============================] - 10s 121ms/step - loss: 1.6351 - accuracy: 0.4098 - val_loss: 1.4313 - val_accuracy: 0.5109
# Epoch 31/100
# 80/80 [==============================] - 10s 122ms/step - loss: 1.6586 - accuracy: 0.4191 - val_loss: 1.4639 - val_accuracy: 0.4875
# Epoch 32/100
# 80/80 [==============================] - 10s 122ms/step - loss: 1.6181 - accuracy: 0.4320 - val_loss: 1.4213 - val_accuracy: 0.5172
# Epoch 33/100
# 80/80 [==============================] - 10s 120ms/step - loss: 1.5915 - accuracy: 0.4414 - val_loss: 1.5028 - val_accuracy: 0.4969
# Epoch 34/100
# 80/80 [==============================] - 10s 120ms/step - loss: 1.5839 - accuracy: 0.4324 - val_loss: 1.4238 - val_accuracy: 0.5094
# Epoch 35/100
# 80/80 [==============================] - 10s 122ms/step - loss: 1.5836 - accuracy: 0.4355 - val_loss: 1.4835 - val_accuracy: 0.4531
# Epoch 36/100
# 80/80 [==============================] - 10s 120ms/step - loss: 1.5847 - accuracy: 0.4387 - val_loss: 1.3861 - val_accuracy: 0.5297
# Epoch 37/100
# 80/80 [==============================] - 10s 120ms/step - loss: 1.5902 - accuracy: 0.4375 - val_loss: 1.4052 - val_accuracy: 0.5359
# Epoch 38/100
# 80/80 [==============================] - 10s 120ms/step - loss: 1.5727 - accuracy: 0.4437 - val_loss: 1.4556 - val_accuracy: 0.4719
# Epoch 39/100
# 80/80 [==============================] - 10s 120ms/step - loss: 1.5548 - accuracy: 0.4500 - val_loss: 1.3840 - val_accuracy: 0.5375
# Epoch 40/100
# 80/80 [==============================] - 10s 121ms/step - loss: 1.5326 - accuracy: 0.4617 - val_loss: 1.3726 - val_accuracy: 0.5250
# Epoch 41/100
# 80/80 [==============================] - 10s 120ms/step - loss: 1.5810 - accuracy: 0.4363 - val_loss: 1.3696 - val_accuracy: 0.5437
# Epoch 42/100
# 80/80 [==============================] - 10s 124ms/step - loss: 1.5453 - accuracy: 0.4559 - val_loss: 1.3652 - val_accuracy: 0.5312
# Epoch 43/100
# 80/80 [==============================] - 10s 122ms/step - loss: 1.5240 - accuracy: 0.4578 - val_loss: 1.3489 - val_accuracy: 0.5359
# Epoch 44/100
# 80/80 [==============================] - 9s 118ms/step - loss: 1.5549 - accuracy: 0.4496 - val_loss: 1.3535 - val_accuracy: 0.5359
# Epoch 45/100
# 80/80 [==============================] - 9s 118ms/step - loss: 1.5442 - accuracy: 0.4551 - val_loss: 1.3550 - val_accuracy: 0.5531
# Epoch 46/100
# 80/80 [==============================] - 10s 119ms/step - loss: 1.5317 - accuracy: 0.4621 - val_loss: 1.3554 - val_accuracy: 0.5422
# Epoch 47/100
# 80/80 [==============================] - 9s 117ms/step - loss: 1.5319 - accuracy: 0.4648 - val_loss: 1.3459 - val_accuracy: 0.5359
# Epoch 48/100
# 80/80 [==============================] - 10s 119ms/step - loss: 1.5020 - accuracy: 0.4734 - val_loss: 1.3911 - val_accuracy: 0.4922
# Epoch 49/100
# 80/80 [==============================] - 9s 118ms/step - loss: 1.5109 - accuracy: 0.4594 - val_loss: 1.3130 - val_accuracy: 0.5531
# Epoch 50/100
# 80/80 [==============================] - 9s 117ms/step - loss: 1.5165 - accuracy: 0.4652 - val_loss: 1.3114 - val_accuracy: 0.5672
# Epoch 51/100
# 80/80 [==============================] - 9s 118ms/step - loss: 1.4865 - accuracy: 0.4805 - val_loss: 1.3377 - val_accuracy: 0.5328
# Epoch 52/100
# 80/80 [==============================] - 10s 122ms/step - loss: 1.4842 - accuracy: 0.4797 - val_loss: 1.3198 - val_accuracy: 0.5391
# Epoch 53/100
# 80/80 [==============================] - 10s 121ms/step - loss: 1.4873 - accuracy: 0.4859 - val_loss: 1.2951 - val_accuracy: 0.5625
# Epoch 54/100
# 80/80 [==============================] - 10s 119ms/step - loss: 1.4930 - accuracy: 0.4727 - val_loss: 1.3260 - val_accuracy: 0.5484
# Epoch 55/100
# 80/80 [==============================] - 9s 118ms/step - loss: 1.5041 - accuracy: 0.4852 - val_loss: 1.3128 - val_accuracy: 0.5656
# Epoch 56/100
# 80/80 [==============================] - 9s 118ms/step - loss: 1.4916 - accuracy: 0.4848 - val_loss: 1.2846 - val_accuracy: 0.5688
# Epoch 57/100
# 80/80 [==============================] - 9s 117ms/step - loss: 1.4839 - accuracy: 0.4684 - val_loss: 1.2888 - val_accuracy: 0.5641
# Epoch 58/100
# 80/80 [==============================] - 9s 118ms/step - loss: 1.4715 - accuracy: 0.4777 - val_loss: 1.2863 - val_accuracy: 0.5609
# Epoch 59/100
# 80/80 [==============================] - 9s 118ms/step - loss: 1.4574 - accuracy: 0.4945 - val_loss: 1.2916 - val_accuracy: 0.5688
# Epoch 60/100
# 80/80 [==============================] - 10s 120ms/step - loss: 1.4693 - accuracy: 0.4707 - val_loss: 1.2850 - val_accuracy: 0.5547
# Epoch 61/100
# 80/80 [==============================] - 9s 118ms/step - loss: 1.4599 - accuracy: 0.4984 - val_loss: 1.2991 - val_accuracy: 0.5469
# Epoch 62/100
# 80/80 [==============================] - 10s 119ms/step - loss: 1.4707 - accuracy: 0.4809 - val_loss: 1.2693 - val_accuracy: 0.5703
# Epoch 63/100
# 80/80 [==============================] - 10s 119ms/step - loss: 1.4525 - accuracy: 0.4852 - val_loss: 1.2705 - val_accuracy: 0.5594
# Epoch 64/100
# 80/80 [==============================] - 10s 120ms/step - loss: 1.4607 - accuracy: 0.4859 - val_loss: 1.2758 - val_accuracy: 0.5578
# Epoch 65/100
# 80/80 [==============================] - 9s 118ms/step - loss: 1.4468 - accuracy: 0.4941 - val_loss: 1.3168 - val_accuracy: 0.5469
# Epoch 66/100
# 80/80 [==============================] - 10s 119ms/step - loss: 1.4538 - accuracy: 0.4871 - val_loss: 1.2786 - val_accuracy: 0.5750
# Epoch 67/100
# 80/80 [==============================] - 10s 120ms/step - loss: 1.4427 - accuracy: 0.4941 - val_loss: 1.2628 - val_accuracy: 0.5750
# Epoch 68/100
# 80/80 [==============================] - 9s 117ms/step - loss: 1.4439 - accuracy: 0.4934 - val_loss: 1.2781 - val_accuracy: 0.5578
# Epoch 69/100
# 80/80 [==============================] - 9s 118ms/step - loss: 1.4508 - accuracy: 0.5000 - val_loss: 1.2850 - val_accuracy: 0.5672
# Epoch 70/100
# 80/80 [==============================] - 9s 117ms/step - loss: 1.4220 - accuracy: 0.4965 - val_loss: 1.2919 - val_accuracy: 0.5422
# Epoch 71/100
# 80/80 [==============================] - 9s 118ms/step - loss: 1.4388 - accuracy: 0.4945 - val_loss: 1.2637 - val_accuracy: 0.5656
# Epoch 72/100
# 80/80 [==============================] - 9s 118ms/step - loss: 1.4387 - accuracy: 0.4977 - val_loss: 1.2611 - val_accuracy: 0.5734
# Epoch 73/100
# 80/80 [==============================] - 10s 124ms/step - loss: 1.4494 - accuracy: 0.4879 - val_loss: 1.2879 - val_accuracy: 0.5750
# Epoch 74/100
# 80/80 [==============================] - 9s 118ms/step - loss: 1.4091 - accuracy: 0.4922 - val_loss: 1.2617 - val_accuracy: 0.5766
# Epoch 75/100
# 80/80 [==============================] - 9s 117ms/step - loss: 1.4192 - accuracy: 0.5012 - val_loss: 1.3090 - val_accuracy: 0.5562
# Epoch 76/100
# 80/80 [==============================] - 9s 118ms/step - loss: 1.4157 - accuracy: 0.4980 - val_loss: 1.2873 - val_accuracy: 0.5656
# Epoch 77/100
# 80/80 [==============================] - 10s 122ms/step - loss: 1.4378 - accuracy: 0.5082 - val_loss: 1.2595 - val_accuracy: 0.5750
# Epoch 78/100
# 80/80 [==============================] - 10s 121ms/step - loss: 1.4258 - accuracy: 0.5055 - val_loss: 1.2544 - val_accuracy: 0.5781
# Epoch 79/100
# 80/80 [==============================] - 10s 119ms/step - loss: 1.4309 - accuracy: 0.5004 - val_loss: 1.4137 - val_accuracy: 0.5016
# Epoch 80/100
# 80/80 [==============================] - 10s 119ms/step - loss: 1.4226 - accuracy: 0.5035 - val_loss: 1.2454 - val_accuracy: 0.5891
# Epoch 81/100
# 80/80 [==============================] - 10s 120ms/step - loss: 1.4109 - accuracy: 0.5055 - val_loss: 1.3097 - val_accuracy: 0.5484
# Epoch 82/100
# 80/80 [==============================] - 10s 119ms/step - loss: 1.4010 - accuracy: 0.5055 - val_loss: 1.2577 - val_accuracy: 0.5750
# Epoch 83/100
# 80/80 [==============================] - 10s 120ms/step - loss: 1.4017 - accuracy: 0.5043 - val_loss: 1.2270 - val_accuracy: 0.5984
# Epoch 84/100
# 80/80 [==============================] - 10s 119ms/step - loss: 1.4024 - accuracy: 0.5156 - val_loss: 1.2677 - val_accuracy: 0.5813
# Epoch 85/100
# 80/80 [==============================] - 10s 119ms/step - loss: 1.4061 - accuracy: 0.5172 - val_loss: 1.2532 - val_accuracy: 0.5828
# Epoch 86/100
# 80/80 [==============================] - 10s 119ms/step - loss: 1.4033 - accuracy: 0.5078 - val_loss: 1.2317 - val_accuracy: 0.5938
# Epoch 87/100
# 80/80 [==============================] - 10s 119ms/step - loss: 1.3917 - accuracy: 0.5215 - val_loss: 1.2503 - val_accuracy: 0.5781
# Epoch 88/100
# 80/80 [==============================] - 9s 117ms/step - loss: 1.3789 - accuracy: 0.5133 - val_loss: 1.2579 - val_accuracy: 0.5734
# Epoch 89/100
# 80/80 [==============================] - 9s 118ms/step - loss: 1.3947 - accuracy: 0.5051 - val_loss: 1.2955 - val_accuracy: 0.5531
# Epoch 90/100
# 80/80 [==============================] - 9s 118ms/step - loss: 1.4275 - accuracy: 0.5023 - val_loss: 1.2364 - val_accuracy: 0.5922
# Epoch 91/100
# 80/80 [==============================] - 10s 121ms/step - loss: 1.3724 - accuracy: 0.5180 - val_loss: 1.2118 - val_accuracy: 0.6031
# Epoch 92/100
# 80/80 [==============================] - 10s 121ms/step - loss: 1.3670 - accuracy: 0.5234 - val_loss: 1.2129 - val_accuracy: 0.5953
# Epoch 93/100
# 80/80 [==============================] - 10s 119ms/step - loss: 1.3762 - accuracy: 0.5148 - val_loss: 1.2343 - val_accuracy: 0.5828
# Epoch 94/100
# 80/80 [==============================] - 10s 123ms/step - loss: 1.3688 - accuracy: 0.5145 - val_loss: 1.2201 - val_accuracy: 0.5891
# Epoch 95/100
# 80/80 [==============================] - 9s 118ms/step - loss: 1.4056 - accuracy: 0.5148 - val_loss: 1.2164 - val_accuracy: 0.5906
# Epoch 96/100
# 80/80 [==============================] - 10s 119ms/step - loss: 1.3766 - accuracy: 0.5297 - val_loss: 1.2419 - val_accuracy: 0.5891
# Epoch 97/100
# 80/80 [==============================] - 10s 120ms/step - loss: 1.3743 - accuracy: 0.5234 - val_loss: 1.3029 - val_accuracy: 0.5547
# Epoch 98/100
# 80/80 [==============================] - 9s 117ms/step - loss: 1.3687 - accuracy: 0.5223 - val_loss: 1.2074 - val_accuracy: 0.6047
# Epoch 99/100
# 80/80 [==============================] - 9s 118ms/step - loss: 1.3641 - accuracy: 0.5258 - val_loss: 1.2244 - val_accuracy: 0.5891
# Epoch 100/100
# 80/80 [==============================] - 9s 117ms/step - loss: 1.3787 - accuracy: 0.5141 - val_loss: 1.2132 - val_accuracy: 0.6062

# %%
best_model = load_model(model_path4)
best_model.evaluate(X_test, Y_test)
# Out:
# 25/25 [==============================] - 0s 6ms/step - loss: 1.2740 - accuracy: 0.5725
# [1.2739533185958862, 0.5724999904632568]

# %%
y_acc = hist4.history['accuracy']
y_vloss = hist4.history['val_loss']
xs = np.arange(1, len(y_acc) + 1)

plt.figure(figsize = (12, 6))
plt.plot(xs, y_acc, label = 'accuracy')
plt.plot(xs, y_vloss, label = 'validation_loss')
plt.xlabel('Epoch')
plt.title('gray_NewdelNois_rms')
plt.legend(), plt.grid()
plt.show()

# %% [markdown]
# - 에포크, 배치사이즈 증가

# %%
model_path5 = './gray_NewdelNois_rms2.h5'
mc5 = ModelCheckpoint(model_path5, moniter = 'val_loss', verbose = 1, save_best_only = True)
es5 = EarlyStopping(patience = 20)
with tf.device("/device:GPU:0"):
    hist5 = model.fit(
    datagen4.flow(X_train, Y_train, batch_size=12), verbose=1,
    validation_data=(X_valid, Y_valid), epochs = 200, callbacks=[mc5, es5]
    )
# Out:
# Epoch 1/200
# 214/214 [==============================] - 26s 120ms/step - loss: 1.3405 - accuracy: 0.5332 - val_loss: 1.2126 - val_accuracy: 0.5797
# Epoch 2/200
# 214/214 [==============================] - 25s 119ms/step - loss: 1.3457 - accuracy: 0.5375 - val_loss: 1.1997 - val_accuracy: 0.6141
# Epoch 3/200
# 214/214 [==============================] - 25s 119ms/step - loss: 1.3178 - accuracy: 0.5285 - val_loss: 1.1720 - val_accuracy: 0.6187
# Epoch 4/200
# 214/214 [==============================] - 25s 119ms/step - loss: 1.3311 - accuracy: 0.5289 - val_loss: 1.2132 - val_accuracy: 0.6078
# Epoch 5/200
# 214/214 [==============================] - 25s 119ms/step - loss: 1.3532 - accuracy: 0.5332 - val_loss: 1.1998 - val_accuracy: 0.5938
# Epoch 6/200
# 214/214 [==============================] - 26s 120ms/step - loss: 1.3360 - accuracy: 0.5344 - val_loss: 1.2101 - val_accuracy: 0.5969
# Epoch 7/200
# 214/214 [==============================] - 26s 120ms/step - loss: 1.3358 - accuracy: 0.5398 - val_loss: 1.2003 - val_accuracy: 0.6031
# Epoch 8/200
# 214/214 [==============================] - 25s 117ms/step - loss: 1.3422 - accuracy: 0.5383 - val_loss: 1.1941 - val_accuracy: 0.6094
# Epoch 9/200
# 214/214 [==============================] - 25s 119ms/step - loss: 1.3385 - accuracy: 0.5262 - val_loss: 1.2191 - val_accuracy: 0.6047
# Epoch 10/200
# 214/214 [==============================] - 26s 120ms/step - loss: 1.3472 - accuracy: 0.5363 - val_loss: 1.2303 - val_accuracy: 0.5766
# Epoch 11/200
# 214/214 [==============================] - 25s 118ms/step - loss: 1.3504 - accuracy: 0.5355 - val_loss: 1.1923 - val_accuracy: 0.6000
# Epoch 12/200
# 214/214 [==============================] - 25s 119ms/step - loss: 1.3617 - accuracy: 0.5207 - val_loss: 1.2105 - val_accuracy: 0.5969
# Epoch 13/200
# 214/214 [==============================] - 26s 121ms/step - loss: 1.3487 - accuracy: 0.5305 - val_loss: 1.1805 - val_accuracy: 0.6141

# %%
best_model = load_model(model_path5)
best_model.evaluate(X_test, Y_test)
# Out:
# 25/25 [==============================] - 0s 7ms/step - loss: 1.1986 - accuracy: 0.6025
# [1.1986076831817627, 0.6025000214576721]

# %%
y_acc = hist4.history['accuracy']
y_vloss = hist4.history['val_loss']
xs = np.arange(1, len(y_acc) + 1)

plt.figure(figsize = (12, 6))
plt.plot(xs, y_acc, label = 'accuracy')
plt.plot(xs, y_vloss, label = 'validation_loss')
plt.xlabel('Epoch')
plt.title('gray_NewdelNois_rms')
plt.legend(), plt.grid()
plt.show()

# %% [markdown]
# SGD도 활용해보고자 함
# - batch size
# https://inhovation97.tistory.com/32
